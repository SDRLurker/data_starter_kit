# %%
import psycopg2

# Redshift connection 함수
def get_Redshift_connection():
    host = HOST
    redshift_user = ID
    redshift_pass = PW
    port = 5439
    dbname = "dev"
    conn = psycopg2.connect("dbname={dbname} user={user} host={host} password={password} port={port}".format(
        dbname=dbname,
        user=redshift_user,
        password=redshift_pass,
        host=host,
        port=port
    ))
    conn.set_session(autocommit=True)
    return conn.cursor()
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# # ETL 함수를 하나씩 정의

# %%
import requests

def extract(url):
    f = requests.get(link)
    return (f.text)

# %%
def transform(text):
    lines = text.split("\n")
    return lines

# %%
def load(lines):
    # BEGIN과 END를 사용해서 SQL 결과를 트랜잭션으로 만들어주는 것이 좋음
    # BEGIN;TRUNCATE TABLE;INSERT INTO TABLE VALUES ('KEEYONG', 'MALE');END;
    cur = get_Redshift_connection()
    for r in lines:
        if r != '':
            (name, gender) = r.split(",")
            print(name, "-", gender)
            sql = "INSERT INTO sdrlurker.name_gender VALUES ('{name}', '{gender}')".format(name=name, gender=gender)
            print(sql)
            cur.execute(sql)

# %% [markdown]
# # 이제 Extract부터 함수를 하나씩 실행

# %%
link = "https://s3-geospatial.s3-us-west-2.amazonaws.com/name_gender.csv"

data = extract(link)

# %%
lines = transform(data)

# %%
load(lines)
# Out:
# name - gender
# INSERT INTO sdrlurker.name_gender VALUES ('name', 'gender')
# Adaleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adaleigh', 'F')
# Amryn - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Amryn', 'Unisex')
# Apurva - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Apurva', 'Unisex')
# Aryion - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aryion', 'M')
# Alixia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alixia', 'F')
# Alyssarose - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alyssarose', 'F')
# Arvell - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arvell', 'M')
# Aibel - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aibel', 'M')
# Atiyyah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Atiyyah', 'F')
# Adlie - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adlie', 'F')
# Anyely - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anyely', 'F')
# Aamoni - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aamoni', 'F')
# Ahman - M
# INSERT INTO sdrlurker.name_gender VALUES ('Ahman', 'M')
# Arlane - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arlane', 'F')
# Armoney - F
# INSERT INTO sdrlurker.name_gender VALUES ('Armoney', 'F')
# Atzhiry - F
# INSERT INTO sdrlurker.name_gender VALUES ('Atzhiry', 'F')
# Antonette - F
# INSERT INTO sdrlurker.name_gender VALUES ('Antonette', 'F')
# Akeelah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Akeelah', 'F')
# Abdikadir - M
# INSERT INTO sdrlurker.name_gender VALUES ('Abdikadir', 'M')
# Arinze - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arinze', 'M')
# Arshaun - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arshaun', 'M')
# Alexandro - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alexandro', 'M')
# Ayriauna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ayriauna', 'F')
# Aqib - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aqib', 'M')
# Alleya - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alleya', 'F')
# Aavah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aavah', 'F')
# Anesti - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Anesti', 'Unisex')
# Adalaide - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adalaide', 'F')
# Analena - F
# INSERT INTO sdrlurker.name_gender VALUES ('Analena', 'F')
# Alaeyah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alaeyah', 'F')
# Albena - F
# INSERT INTO sdrlurker.name_gender VALUES ('Albena', 'F')
# Aimi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aimi', 'F')
# Adwaith - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adwaith', 'M')
# Arkady - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arkady', 'M')
# Astyn - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Astyn', 'Unisex')
# Adelee - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adelee', 'F')
# Agata - F
# INSERT INTO sdrlurker.name_gender VALUES ('Agata', 'F')
# Alegna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alegna', 'F')
# Altan - M
# INSERT INTO sdrlurker.name_gender VALUES ('Altan', 'M')
# Ahnaleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahnaleigh', 'F')
# Algie - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Algie', 'Unisex')
# Ashanti - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ashanti', 'F')
# Aislyn - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aislyn', 'F')
# Adaleine - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adaleine', 'F')
# Anthnoy - M
# INSERT INTO sdrlurker.name_gender VALUES ('Anthnoy', 'M')
# Algernon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Algernon', 'M')
# Aeryona - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aeryona', 'F')
# Adrinne - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adrinne', 'F')
# Addell - F
# INSERT INTO sdrlurker.name_gender VALUES ('Addell', 'F')
# Avril - F
# INSERT INTO sdrlurker.name_gender VALUES ('Avril', 'F')
# Ahni - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahni', 'F')
# Aimon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aimon', 'M')
# Adolpho - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adolpho', 'M')
# Ahuva - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahuva', 'F')
# Aurielle - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aurielle', 'F')
# Aveana - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aveana', 'F')
# Aliyia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aliyia', 'F')
# Alesander - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alesander', 'M')
# Adnrea - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adnrea', 'F')
# Anjae - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anjae', 'F')
# Alvine - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alvine', 'F')
# Adorah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adorah', 'F')
# Adlemi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adlemi', 'F')
# Alesi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alesi', 'F')
# Alontae - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alontae', 'M')
# Antonny - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antonny', 'M')
# Adarah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adarah', 'F')
# Ayreanna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ayreanna', 'F')
# Antyon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antyon', 'M')
# Andia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Andia', 'F')
# Ashla - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ashla', 'F')
# Aspyn - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aspyn', 'F')
# Antwanett - F
# INSERT INTO sdrlurker.name_gender VALUES ('Antwanett', 'F')
# Aundreia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aundreia', 'F')
# Audella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Audella', 'F')
# Amari - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Amari', 'Unisex')
# Arsha - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Arsha', 'Unisex')
# Aricella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aricella', 'F')
# Adan - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adan', 'M')
# Apasra - F
# INSERT INTO sdrlurker.name_gender VALUES ('Apasra', 'F')
# Alaysha - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alaysha', 'F')
# Anderson - M
# INSERT INTO sdrlurker.name_gender VALUES ('Anderson', 'M')
# Aurelius - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aurelius', 'M')
# Aerial - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aerial', 'F')
# Averleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Averleigh', 'F')
# Aslean - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aslean', 'F')
# Arniesha - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arniesha', 'F')
# Asyana - F
# INSERT INTO sdrlurker.name_gender VALUES ('Asyana', 'F')
# Annjane - F
# INSERT INTO sdrlurker.name_gender VALUES ('Annjane', 'F')
# Amabella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Amabella', 'F')
# Austinjohn - M
# INSERT INTO sdrlurker.name_gender VALUES ('Austinjohn', 'M')
# Arloween - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arloween', 'F')
# Alula - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alula', 'M')
# Anemone - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anemone', 'F')
# Amorina - F
# INSERT INTO sdrlurker.name_gender VALUES ('Amorina', 'F')
# Anureet - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anureet', 'F')
# Arric - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arric', 'M')
# Antonne - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antonne', 'M')
# Alyre - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alyre', 'M')
# Annaise - F
# INSERT INTO sdrlurker.name_gender VALUES ('Annaise', 'F')

# %%
# %load_ext sql

# %%
# ID와 PW를 자신의 환경에 맞게 수정(ID:PW 변수 하드코딩 해야함.)
# %sql postgresql://ID:PW@HOST:5439/dev
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# 'Connected: sdrlurker@dev'

# %% [markdown]
# # Assignment #1 - Colab Python 코드 개선하기
#
# 1. 헤더가 레코드로 추가되는 문제 해결하기
#
# 2. Idempotent하게 잡을 만들기
#
#   a. 여러 번 실행해도 동일한 결과가 나오게 만들기
# 3. Transaction을 사용해보기

# %%
# Redshift connection 함수
def get_Redshift_connection():
    host = HOST
    redshift_user = ID
    redshift_pass = PW
    port = 5439
    dbname = "dev"
    conn = psycopg2.connect("dbname={dbname} user={user} host={host} password={password} port={port}".format(
        dbname=dbname,
        user=redshift_user,
        password=redshift_pass,
        host=host,
        port=port
    ))
    # 3. Transaction 사용을 위해 autocommit=False로 변경
    conn.set_session(autocommit=False)
    return conn

# %%
def load(lines):
    def execute(sql):
        print(sql)
        cur.execute(sql)
    # 3. Transaction을 위해 TRUNCATE를 DELETE로 변경.
    # BEGIN과 END를 사용해서 SQL 결과를 트랜잭션으로 만들어주는 것이 좋음
    # BEGIN;DELETE TABLE;INSERT INTO TABLE VALUES ('KEEYONG', 'MALE');END;
    with get_Redshift_connection() as conn:
        try:
            cur = conn.cursor()
            execute("BEGIN;DELETE FROM sdrlurker.name_gender;")
            for r in lines:
                if r != '' and not r.startswith('name'): # 1
                    (name, gender) = r.split(",")
                    print(name, "-", gender)
                    sql = "INSERT INTO sdrlurker.name_gender VALUES ('{name}', '{gender}')".format(name=name, gender=gender)
                    execute(sql)
            execute("END;")
        # 2. Idempotent를 위해 rollback 추가.
        except:
            print("<<< rollback >>>")
            conn.rollback()
        finally:
            cur.close()

# %%
load(lines)
# Out:
# BEGIN;DELETE FROM sdrlurker.name_gender;
# Adaleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adaleigh', 'F')
# Amryn - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Amryn', 'Unisex')
# Apurva - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Apurva', 'Unisex')
# Aryion - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aryion', 'M')
# Alixia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alixia', 'F')
# Alyssarose - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alyssarose', 'F')
# Arvell - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arvell', 'M')
# Aibel - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aibel', 'M')
# Atiyyah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Atiyyah', 'F')
# Adlie - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adlie', 'F')
# Anyely - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anyely', 'F')
# Aamoni - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aamoni', 'F')
# Ahman - M
# INSERT INTO sdrlurker.name_gender VALUES ('Ahman', 'M')
# Arlane - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arlane', 'F')
# Armoney - F
# INSERT INTO sdrlurker.name_gender VALUES ('Armoney', 'F')
# Atzhiry - F
# INSERT INTO sdrlurker.name_gender VALUES ('Atzhiry', 'F')
# Antonette - F
# INSERT INTO sdrlurker.name_gender VALUES ('Antonette', 'F')
# Akeelah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Akeelah', 'F')
# Abdikadir - M
# INSERT INTO sdrlurker.name_gender VALUES ('Abdikadir', 'M')
# Arinze - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arinze', 'M')
# Arshaun - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arshaun', 'M')
# Alexandro - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alexandro', 'M')
# Ayriauna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ayriauna', 'F')
# Aqib - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aqib', 'M')
# Alleya - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alleya', 'F')
# Aavah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aavah', 'F')
# Anesti - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Anesti', 'Unisex')
# Adalaide - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adalaide', 'F')
# Analena - F
# INSERT INTO sdrlurker.name_gender VALUES ('Analena', 'F')
# Alaeyah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alaeyah', 'F')
# Albena - F
# INSERT INTO sdrlurker.name_gender VALUES ('Albena', 'F')
# Aimi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aimi', 'F')
# Adwaith - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adwaith', 'M')
# Arkady - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arkady', 'M')
# Astyn - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Astyn', 'Unisex')
# Adelee - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adelee', 'F')
# Agata - F
# INSERT INTO sdrlurker.name_gender VALUES ('Agata', 'F')
# Alegna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alegna', 'F')
# Altan - M
# INSERT INTO sdrlurker.name_gender VALUES ('Altan', 'M')
# Ahnaleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahnaleigh', 'F')
# Algie - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Algie', 'Unisex')
# Ashanti - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ashanti', 'F')
# Aislyn - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aislyn', 'F')
# Adaleine - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adaleine', 'F')
# Anthnoy - M
# INSERT INTO sdrlurker.name_gender VALUES ('Anthnoy', 'M')
# Algernon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Algernon', 'M')
# Aeryona - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aeryona', 'F')
# Adrinne - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adrinne', 'F')
# Addell - F
# INSERT INTO sdrlurker.name_gender VALUES ('Addell', 'F')
# Avril - F
# INSERT INTO sdrlurker.name_gender VALUES ('Avril', 'F')
# Ahni - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahni', 'F')
# Aimon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aimon', 'M')
# Adolpho - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adolpho', 'M')
# Ahuva - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ahuva', 'F')
# Aurielle - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aurielle', 'F')
# Aveana - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aveana', 'F')
# Aliyia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aliyia', 'F')
# Alesander - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alesander', 'M')
# Adnrea - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adnrea', 'F')
# Anjae - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anjae', 'F')
# Alvine - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alvine', 'F')
# Adorah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adorah', 'F')
# Adlemi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adlemi', 'F')
# Alesi - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alesi', 'F')
# Alontae - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alontae', 'M')
# Antonny - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antonny', 'M')
# Adarah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adarah', 'F')
# Ayreanna - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ayreanna', 'F')
# Antyon - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antyon', 'M')
# Andia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Andia', 'F')
# Ashla - F
# INSERT INTO sdrlurker.name_gender VALUES ('Ashla', 'F')
# Aspyn - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aspyn', 'F')
# Antwanett - F
# INSERT INTO sdrlurker.name_gender VALUES ('Antwanett', 'F')
# Aundreia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aundreia', 'F')
# Audella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Audella', 'F')
# Amari - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Amari', 'Unisex')
# Arsha - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Arsha', 'Unisex')
# Aricella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aricella', 'F')
# Adan - M
# INSERT INTO sdrlurker.name_gender VALUES ('Adan', 'M')
# Apasra - F
# INSERT INTO sdrlurker.name_gender VALUES ('Apasra', 'F')
# Alaysha - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alaysha', 'F')
# Anderson - M
# INSERT INTO sdrlurker.name_gender VALUES ('Anderson', 'M')
# Aurelius - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aurelius', 'M')
# Aerial - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aerial', 'F')
# Averleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Averleigh', 'F')
# Aslean - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aslean', 'F')
# Arniesha - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arniesha', 'F')
# Asyana - F
# INSERT INTO sdrlurker.name_gender VALUES ('Asyana', 'F')
# Annjane - F
# INSERT INTO sdrlurker.name_gender VALUES ('Annjane', 'F')
# Amabella - F
# INSERT INTO sdrlurker.name_gender VALUES ('Amabella', 'F')
# Austinjohn - M
# INSERT INTO sdrlurker.name_gender VALUES ('Austinjohn', 'M')
# Arloween - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arloween', 'F')
# Alula - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alula', 'M')
# Anemone - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anemone', 'F')
# Amorina - F
# INSERT INTO sdrlurker.name_gender VALUES ('Amorina', 'F')
# Anureet - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anureet', 'F')
# Arric - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arric', 'M')
# Antonne - M
# INSERT INTO sdrlurker.name_gender VALUES ('Antonne', 'M')
# Alyre - M
# INSERT INTO sdrlurker.name_gender VALUES ('Alyre', 'M')
# Annaise - F
# INSERT INTO sdrlurker.name_gender VALUES ('Annaise', 'F')
# END;

# %%
# %%sql
#
# SELECT * FROM sdrlurker.name_gender;
# Out:
#  * postgresql://sdrlurker:***@HOST:5439/dev
# 100 rows affected.
# [('Adaleigh', 'F'),
#  ('Amryn', 'Unisex'),
#  ('Apurva', 'Unisex'),
#  ('Aryion', 'M'),
#  ('Alixia', 'F'),
#  ('Alyssarose', 'F'),
#  ('Arvell', 'M'),
#  ('Aibel', 'M'),
#  ('Atiyyah', 'F'),
#  ('Adlie', 'F'),
#  ('Anyely', 'F'),
#  ('Aamoni', 'F'),
#  ('Ahman', 'M'),
#  ('Arlane', 'F'),
#  ('Armoney', 'F'),
#  ('Atzhiry', 'F'),
#  ('Antonette', 'F'),
#  ('Akeelah', 'F'),
#  ('Abdikadir', 'M'),
#  ('Arinze', 'M'),
#  ('Arshaun', 'M'),
#  ('Alexandro', 'M'),
#  ('Ayriauna', 'F'),
#  ('Aqib', 'M'),
#  ('Alleya', 'F'),
#  ('Aavah', 'F'),
#  ('Anesti', 'Unisex'),
#  ('Adalaide', 'F'),
#  ('Analena', 'F'),
#  ('Alaeyah', 'F'),
#  ('Albena', 'F'),
#  ('Aimi', 'F'),
#  ('Adwaith', 'M'),
#  ('Arkady', 'M'),
#  ('Astyn', 'Unisex'),
#  ('Adelee', 'F'),
#  ('Agata', 'F'),
#  ('Alegna', 'F'),
#  ('Altan', 'M'),
#  ('Ahnaleigh', 'F'),
#  ('Algie', 'Unisex'),
#  ('Ashanti', 'F'),
#  ('Aislyn', 'F'),
#  ('Adaleine', 'F'),
#  ('Anthnoy', 'M'),
#  ('Algernon', 'M'),
#  ('Aeryona', 'F'),
#  ('Adrinne', 'F'),
#  ('Addell', 'F'),
#  ('Avril', 'F'),
#  ('Ahni', 'F'),
#  ('Aimon', 'M'),
#  ('Adolpho', 'M'),
#  ('Ahuva', 'F'),
#  ('Aurielle', 'F'),
#  ('Aveana', 'F'),
#  ('Aliyia', 'F'),
#  ('Alesander', 'M'),
#  ('Adnrea', 'F'),
#  ('Anjae', 'F'),
#  ('Alvine', 'F'),
#  ('Adorah', 'F'),
#  ('Adlemi', 'F'),
#  ('Alesi', 'F'),
#  ('Alontae', 'M'),
#  ('Antonny', 'M'),
#  ('Adarah', 'F'),
#  ('Ayreanna', 'F'),
#  ('Antyon', 'M'),
#  ('Andia', 'F'),
#  ('Ashla', 'F'),
#  ('Aspyn', 'F'),
#  ('Antwanett', 'F'),
#  ('Aundreia', 'F'),
#  ('Audella', 'F'),
#  ('Amari', 'Unisex'),
#  ('Arsha', 'Unisex'),
#  ('Aricella', 'F'),
#  ('Adan', 'M'),
#  ('Apasra', 'F'),
#  ('Alaysha', 'F'),
#  ('Anderson', 'M'),
#  ('Aurelius', 'M'),
#  ('Aerial', 'F'),
#  ('Averleigh', 'F'),
#  ('Aslean', 'F'),
#  ('Arniesha', 'F'),
#  ('Asyana', 'F'),
#  ('Annjane', 'F'),
#  ('Amabella', 'F'),
#  ('Austinjohn', 'M'),
#  ('Arloween', 'F'),
#  ('Alula', 'M'),
#  ('Anemone', 'F'),
#  ('Amorina', 'F'),
#  ('Anureet', 'F'),
#  ('Arric', 'M'),
#  ('Antonne', 'M'),
#  ('Alyre', 'M'),
#  ('Annaise', 'F')]

# %%
# 실행중단
load(lines)
# Out:
# BEGIN;DELETE FROM sdrlurker.name_gender;
# Adaleigh - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adaleigh', 'F')
# Amryn - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Amryn', 'Unisex')
# Apurva - Unisex
# INSERT INTO sdrlurker.name_gender VALUES ('Apurva', 'Unisex')
# Aryion - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aryion', 'M')
# Alixia - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alixia', 'F')
# Alyssarose - F
# INSERT INTO sdrlurker.name_gender VALUES ('Alyssarose', 'F')
# Arvell - M
# INSERT INTO sdrlurker.name_gender VALUES ('Arvell', 'M')
# Aibel - M
# INSERT INTO sdrlurker.name_gender VALUES ('Aibel', 'M')
# Atiyyah - F
# INSERT INTO sdrlurker.name_gender VALUES ('Atiyyah', 'F')
# Adlie - F
# INSERT INTO sdrlurker.name_gender VALUES ('Adlie', 'F')
# Anyely - F
# INSERT INTO sdrlurker.name_gender VALUES ('Anyely', 'F')
# Aamoni - F
# INSERT INTO sdrlurker.name_gender VALUES ('Aamoni', 'F')
# Ahman - M
# INSERT INTO sdrlurker.name_gender VALUES ('Ahman', 'M')
# Arlane - F
# INSERT INTO sdrlurker.name_gender VALUES ('Arlane', 'F')
# <<< rollback >>>

# %%
# rollback으로 데이터가 그대로 100개로 남아있음.
# %%sql

SELECT * FROM sdrlurker.name_gender;
# Out:
#  * postgresql://sdrlurker:***@HOST:5439/dev
# 100 rows affected.
# [('Adaleigh', 'F'),
#  ('Amryn', 'Unisex'),
#  ('Apurva', 'Unisex'),
#  ('Aryion', 'M'),
#  ('Alixia', 'F'),
#  ('Alyssarose', 'F'),
#  ('Arvell', 'M'),
#  ('Aibel', 'M'),
#  ('Atiyyah', 'F'),
#  ('Adlie', 'F'),
#  ('Anyely', 'F'),
#  ('Aamoni', 'F'),
#  ('Ahman', 'M'),
#  ('Arlane', 'F'),
#  ('Armoney', 'F'),
#  ('Atzhiry', 'F'),
#  ('Antonette', 'F'),
#  ('Akeelah', 'F'),
#  ('Abdikadir', 'M'),
#  ('Arinze', 'M'),
#  ('Arshaun', 'M'),
#  ('Alexandro', 'M'),
#  ('Ayriauna', 'F'),
#  ('Aqib', 'M'),
#  ('Alleya', 'F'),
#  ('Aavah', 'F'),
#  ('Anesti', 'Unisex'),
#  ('Adalaide', 'F'),
#  ('Analena', 'F'),
#  ('Alaeyah', 'F'),
#  ('Albena', 'F'),
#  ('Aimi', 'F'),
#  ('Adwaith', 'M'),
#  ('Arkady', 'M'),
#  ('Astyn', 'Unisex'),
#  ('Adelee', 'F'),
#  ('Agata', 'F'),
#  ('Alegna', 'F'),
#  ('Altan', 'M'),
#  ('Ahnaleigh', 'F'),
#  ('Algie', 'Unisex'),
#  ('Ashanti', 'F'),
#  ('Aislyn', 'F'),
#  ('Adaleine', 'F'),
#  ('Anthnoy', 'M'),
#  ('Algernon', 'M'),
#  ('Aeryona', 'F'),
#  ('Adrinne', 'F'),
#  ('Addell', 'F'),
#  ('Avril', 'F'),
#  ('Ahni', 'F'),
#  ('Aimon', 'M'),
#  ('Adolpho', 'M'),
#  ('Ahuva', 'F'),
#  ('Aurielle', 'F'),
#  ('Aveana', 'F'),
#  ('Aliyia', 'F'),
#  ('Alesander', 'M'),
#  ('Adnrea', 'F'),
#  ('Anjae', 'F'),
#  ('Alvine', 'F'),
#  ('Adorah', 'F'),
#  ('Adlemi', 'F'),
#  ('Alesi', 'F'),
#  ('Alontae', 'M'),
#  ('Antonny', 'M'),
#  ('Adarah', 'F'),
#  ('Ayreanna', 'F'),
#  ('Antyon', 'M'),
#  ('Andia', 'F'),
#  ('Ashla', 'F'),
#  ('Aspyn', 'F'),
#  ('Antwanett', 'F'),
#  ('Aundreia', 'F'),
#  ('Audella', 'F'),
#  ('Amari', 'Unisex'),
#  ('Arsha', 'Unisex'),
#  ('Aricella', 'F'),
#  ('Adan', 'M'),
#  ('Apasra', 'F'),
#  ('Alaysha', 'F'),
#  ('Anderson', 'M'),
#  ('Aurelius', 'M'),
#  ('Aerial', 'F'),
#  ('Averleigh', 'F'),
#  ('Aslean', 'F'),
#  ('Arniesha', 'F'),
#  ('Asyana', 'F'),
#  ('Annjane', 'F'),
#  ('Amabella', 'F'),
#  ('Austinjohn', 'M'),
#  ('Arloween', 'F'),
#  ('Alula', 'M'),
#  ('Anemone', 'F'),
#  ('Amorina', 'F'),
#  ('Anureet', 'F'),
#  ('Arric', 'M'),
#  ('Antonne', 'M'),
#  ('Alyre', 'M'),
#  ('Annaise', 'F')]
